# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 豆瓣小王子评论解析

# %%
import requests 
from bs4 import BeautifulSoup 
url="https://book.douban.com/subject/1084336/comments/"
headers={'User-Agent':'Mozilla/5.0(Windows NT 10.0; wow64)  AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
try:
    r=requests.get(url,headers=headers)
    r.raise_for_status()
    r.encoding=r.apparent_encoding 
except:
    print("爬取失败")
soup = BeautifulSoup(r.text, 'lxml') 
pattern = soup.find_all('span', 'short') 
for item in pattern: 
  print(item.string)
# Out:
# 十几岁的时候渴慕着小王子，一天之间可以看四十四次日落。是在多久之后才明白，看四十四次日落的小王子，他有多么难过。
# 读了好多年，终于读完了，但是实在共鸣不起来，虽然知道那些道理，但真的觉得没什么了不起啊，是我还太幼稚吗？
# 我的玫瑰花儿，只有四个微不足道的刺，用来抵御这个世界。
# 说实话 我看不太懂 但还是跟风给个5星吧 以显示我也是有思想有学识之人
# 虽然我实在幼稚，但我并不怎么喜欢孩童般的纯净，我只爱风浪过后的平静，流水打磨出的清亮，大雪纷飞时的安宁，沧桑看透的纯真，我爱眼冷心热的庄子，人究竟无所逃于天地之间，各适其性，做自己认为有意义的事就好了，无论是统治宇宙还是喝酒点灯，对他们来说，都比爱一朵玫瑰重要，这不是很好的么
# 一边读一边很想哭。太寂寞了。人类真的太寂寞了。
# 是你浪费在我身上的时间 使我变得 如此珍贵
# 不能理解的是，為什么它忽然紅成這樣？
# 如果你是小王子，我就是那捉鸡的狐狸，求你驯养了我，却又对你说要你回去对你的玫瑰花负责。还大方地以为只要看见了麦田就会想起你头发的颜色。我却永远无法随你回到B-612星球。现在觉得，我可能只是猴面包树而已。
# 狐狸告诉小王子的秘密是：用心去看才看得清楚；是分离让小王子更思念他的玫瑰；爱就是责任。
#
# 我老觉得小狐狸跟小王子是在搞GAY
# 原来在我还不懂爱情的时候就爱上了你
# 痛苦迷茫不是因为成为了“可笑”的大人，而是成为大人却没有真正长大。所以回过头来想要从怀念童年中解脱缓解痛苦那是本末倒置的做法。如果你作为一个成年人觉得痛苦，原因不是因为你“成年”了，也不是因为是生而为“人”，而是“你”停止了思考停止了学习。
# 第一遍读时，我才4岁。等到真的读懂，才明白为什么这是一部“童话”。
# 他像一颗树那样倒了下去
# It is the time you have wasted for your rose that makes your rose so important.
# 狐狸再好又有什么用，他还是爱玫瑰花
# 你要非常有耐心，”狐狸说，“首先，你要在离我有点远的地方坐下，就像这样，坐在草地上。我会偷偷地看你，你不要说话。语言是误解的根源。但你每天都要坐得离我更近一点
# 爱屋及乌，爱一个人会让周围的一切变得美好，连麦浪的金黄都会让人心醉。
#
# ...

# %% [markdown]
# ## 政府报告实例

# %%
import requests 
from bs4 import BeautifulSoup 
url=" http://www.gov.cn/zhuanti/2020lhzfgzbg/"
headers={'User-Agent':'Mozilla/5.0'}
try:
    r=requests.get(url,headers=headers)
    r.raise_for_status()
    r.encoding=r.apparent_encoding 
except:
    print("爬取失败")
soup = BeautifulSoup(r.text, 'lxml') 
pattern = soup.find("div", class_="zhj-bbqw") 
#pattern = soup.find("div", class_="zhj-bbqw-cont") 
print(pattern.text)
# Out:
# 政府工作报告
# ——2020年5月22日在第十三届全国人民代表大会第三次会议上
# 国务院总理 李克强
# 各位代表：
# 现在，我代表国务院，向大会报告政府工作，请予审议，并请全国政协委员提出意见。
# 这次新冠肺炎疫情，是新中国成立以来我国遭遇的传播速度最快、感染范围最广、防控难度最大的重大突发公共卫生事件。在以习近平同志为核心的党中央坚强领导下，经过全国上下和广大人民群众艰苦卓绝努力并付出牺牲，疫情防控取得重大战略成果。当前，疫情尚未结束，发展任务异常艰巨。要努力把疫情造成的损失降到最低，努力完成今年经济社会发展目标任务。
# 一、2019年和今年以来工作回顾
# 去年，我国发展面临诸多困难挑战。世界经济增长低迷，国际经贸摩擦加剧，国内经济下行压力加大。以习近平同志为核心的党中央团结带领全国各族人民攻坚克难，完成全年主要目标任务，为全面建成小康社会打下决定性基础。
# ——经济运行总体平稳。国内生产总值达到99.1万亿元，增长6.1%。城镇新增就业1352万人，调查失业率在5.3%以下。居民消费价格上涨2.9%。国际收支基本平衡。
# ——经济结构和区域布局继续优化。社会消费品零售总额超过40万亿元，消费持续发挥主要拉动作用。先进制造业、现代服务业较快增长。粮食产量1.33万亿斤。常住人口城镇化率首次超过60%，重大区域战略深入实施。
# ——发展新动能不断增强。科技创新取得一批重大成果。新兴产业持续壮大，传统产业加快升级。大众创业万众创新深入开展，企业数量日均净增1万户以上。
# ——改革开放迈出重要步伐。供给侧结构性改革继续深化，重要领域改革取得新突破。减税降费2.36万亿元，超过原定的近2万亿元规模，制造业和小微企业受益最多。政府机构改革任务完成。“放管服”改革纵深推进。设立科创板。共建“一带一路”取得新成效。出台外商投资法实施条例，增设上海自贸试验区新片区。外贸外资保持稳定。
# ——三大攻坚战取得关键进展。农村贫困人口减少1109万，贫困发生率降至0.6%，脱贫攻坚取得决定性成就。污染防治持续推进，主要污染物排放量继续下降，生态环境总体改善。金融运行总体平稳。
# ...

# %%
import requests 
from bs4 import BeautifulSoup 
url="https://book.zongheng.com/chapter/912802/59031605.html"
headers={'User-Agent':'Mozilla/5.0(Windows NT 10.0; wow64)  AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
try:
    r=requests.get(url,headers=headers)
    r.raise_for_status()
    r.encoding=r.apparent_encoding 
except:
    print("爬取失败")
soup = BeautifulSoup(r.text, 'lxml') 
title = soup.find('title')
title.text
# Out:
# '第一章 抛诱饵钓上大鱼，贪婪心愿者上钩_大国良臣小说最新章节,在线阅读,纵横小说'

# %% [markdown]
# ## 动态网页爬取

# %%
import requests
r=requests.get('https://feed.mix.sina.com.cn/api/roll/get?pageid=153&lid=2509&k=&num=50&page=1&r=0.376708357257022&callback=jQuery1112016559304665244534_1749125764004&_=1749125764008')
r.text[:1000]
# Out:
# 'try{jQuery1112016559304665244534_1749125764004({"result":{"status":{"code":0,"msg":"succ"},"timestamp":"Thu Jun 05 23:14:41 +0800 2025","top":[],"pdps":[],"cre":[],"total":101325,"end":1749130793,"start":1749136308,"lid":2509,"rtime":1749136481,"data":[{"icons":"","is_cre_manual":"0","hqChart":"{\\"stockCharts\\":\\"\\\\u7f8e\\\\u80a1\\\\u5206\\\\u65f6\\\\u56fe\\",\\"stockCode\\":\\"\\",\\"stockMarket\\":\\"us\\",\\"mulStockChart\\":\\"\\",\\"isStaticStock\\":\\"\\"}","intime":"1749136364","channelid":"31","ctime":"1749136308","mtime":"1749136360","authoruid":"0","level":"1","vid":"0","ipad_vid":"0","video_time_length":"0","categoryid":"1","mediaid":"0","templateid":"0","productid":"0","ext_0":"0","ext_1":"0","ext_2":"0","ext_3":"0","ext_4":"0","docid":"comos:neyzwyu3217343","url":"https:\\/\\/finance.sina.com.cn\\/stock\\/usstock\\/c\\/2025-06-05\\/doc-ineyzwyu3217343.shtml","urls":"[\\"https:\\\\\\/\\\\\\/finance.sina.com.cn\\\\\\/stock\\\\\\/usstock\\\\\\/c\\\\\\/2025-06-05\\\\\\
# ...

# %%
import requests
r=requests.get('https://feed.mix.sina.com.cn/api/roll/get?pageid=153&lid=2509&k=&num=50&page=1&r=0.5853592634293099&callback=jQuery1112049650008100909315_1714398945512&_=1714398945525')
r.text[:1000]
# Out:
# 'try{jQuery1112049650008100909315_1714398945512({"result":{"status":{"code":0,"msg":"succ"},"timestamp":"Thu Jun 05 23:36:50 +0800 2025","top":[],"pdps":[],"cre":[],"total":101328,"end":1749130880,"start":1749137428,"lid":2509,"rtime":1749137810,"data":[{"icons":"","is_cre_manual":"0","hqChart":"{\\"stockCharts\\":\\"no\\",\\"stockCode\\":\\"\\",\\"stockMarket\\":\\"\\",\\"mulStockChart\\":\\"\\",\\"isStaticStock\\":\\"\\"}","intime":"1749137445","channelid":"31","ctime":"1749137428","mtime":"1749137439","authoruid":"0","level":"2","vid":"0","ipad_vid":"0","video_time_length":"0","categoryid":"1","mediaid":"0","templateid":"0","productid":"0","ext_0":"0","ext_1":"0","ext_2":"0","ext_3":"0","ext_4":"0","docid":"comos:neyzwyu3225629","url":"https:\\/\\/finance.sina.com.cn\\/stock\\/usstock\\/c\\/2025-06-05\\/doc-ineyzwyu3225629.shtml","urls":"[\\"https:\\\\\\/\\\\\\/finance.sina.com.cn\\\\\\/stock\\\\\\/usstock\\\\\\/c\\\\\\/2025-06-05\\\\\\/doc-ineyzwyu3225629.shtml\\"]","wapurl":"htt
# ...

# %%
r.text.encode('utf-8').decode('unicode-escape')
# Out:
# <ipython-input-52-798fdb811c3c>:1: DeprecationWarning: invalid escape sequence '\/'
#   r.text.encode('utf-8').decode('unicode-escape')
# ...
