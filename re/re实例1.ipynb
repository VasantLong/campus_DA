# %%
import requests 
from bs4 import BeautifulSoup 
import re
url="https://book.douban.com/subject/1084336/comments/"
headers={'User-Agent':'Mozilla/5.0'}
try:
    r=requests.get(url,headers=headers)
    r.raise_for_status()
    r.encoding=r.apparent_encoding 
except:
    print("爬取失败")
soup = BeautifulSoup(r.text, 'lxml') 

pattern_s = re.compile('<span class="user-stars allstar(.*?) rating"') #使用正则匹配将评分设置为.*?，并用括号来捕获该评分
p = re.findall(pattern_s, r.text)
print(p)
# Out:
# ['50', '50', '50', '30', '50', '50', '50', '40', '40', '20', '50', '50', '40', '50', '40', '50', '30']

# %%
import requests 
from bs4 import BeautifulSoup 
import re
url="https://book.douban.com/subject/1084336/comments/"
headers={'User-Agent':'Mozilla/5.0'}
try:
    r=requests.get(url,headers=headers)
    r.raise_for_status()
    r.encoding=r.apparent_encoding 
except:
    print("爬取失败")
soup = BeautifulSoup(r.text, 'lxml') 
pattern = soup.find_all('span', 'short') 
for item in pattern: 
  print(item.string) 
pattern_s = re.compile('<span class="user-stars allstar(.*?) rating"') #使用正则匹配将评分设置为.*?，并用括号来捕获该评分
p = re.findall(pattern_s, r.text)
s = 0
for star in p:
  s += int(star)
print('该书总分为%d'%s)
# Out:
# 十几岁的时候渴慕着小王子，一天之间可以看四十四次日落。是在多久之后才明白，看四十四次日落的小王子，他有多么难过。
# 读了好多年，终于读完了，但是实在共鸣不起来，虽然知道那些道理，但真的觉得没什么了不起啊，是我还太幼稚吗？
# 我的玫瑰花儿，只有四个微不足道的刺，用来抵御这个世界。
# 说实话 我看不太懂 但还是跟风给个5星吧 以显示我也是有思想有学识之人
# 虽然我实在幼稚，但我并不怎么喜欢孩童般的纯净，我只爱风浪过后的平静，流水打磨出的清亮，大雪纷飞时的安宁，沧桑看透的纯真，我爱眼冷心热的庄子，人究竟无所逃于天地之间，各适其性，做自己认为有意义的事就好了，无论是统治宇宙还是喝酒点灯，对他们来说，都比爱一朵玫瑰重要，这不是很好的么
# 一边读一边很想哭。太寂寞了。人类真的太寂寞了。
# 是你浪费在我身上的时间 使我变得 如此珍贵
# 不能理解的是，為什么它忽然紅成這樣？
# 如果你是小王子，我就是那捉鸡的狐狸，求你驯养了我，却又对你说要你回去对你的玫瑰花负责。还大方地以为只要看见了麦田就会想起你头发的颜色。我却永远无法随你回到B-612星球。现在觉得，我可能只是猴面包树而已。
# 狐狸告诉小王子的秘密是：用心去看才看得清楚；是分离让小王子更思念他的玫瑰；爱就是责任。
#
# 我老觉得小狐狸跟小王子是在搞GAY
# 原来在我还不懂爱情的时候就爱上了你
# 痛苦迷茫不是因为成为了“可笑”的大人，而是成为大人却没有真正长大。所以回过头来想要从怀念童年中解脱缓解痛苦那是本末倒置的做法。如果你作为一个成年人觉得痛苦，原因不是因为你“成年”了，也不是因为是生而为“人”，而是“你”停止了思考停止了学习。
# 第一遍读时，我才4岁。等到真的读懂，才明白为什么这是一部“童话”。
# 他像一颗树那样倒了下去
# It is the time you have wasted for your rose that makes your rose so important.
# 狐狸再好又有什么用，他还是爱玫瑰花
# 你要非常有耐心，”狐狸说，“首先，你要在离我有点远的地方坐下，就像这样，坐在草地上。我会偷偷地看你，你不要说话。语言是误解的根源。但你每天都要坐得离我更近一点
# 爱屋及乌，爱一个人会让周围的一切变得美好，连麦浪的金黄都会让人心醉。
#
# ...

# %%
for link in soup.find_all('a') :   #搜索到所有<a>标签
   print(link.get('href'))           #解析<a>标签格式，用get('href')方法提取href属性对应值，即url链接内容
# Out:
# https://accounts.douban.com/passport/login?source=book
# https://www.douban.com/doubanapp/app?channel=top-nav
# https://www.douban.com/doubanapp/app?channel=qipao
# javascript: void 0;
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android
# https://www.douban.com
# https://book.douban.com
# https://movie.douban.com
# https://music.douban.com
# https://www.douban.com/location
# https://www.douban.com/group
# https://read.douban.com/?dcs=top-nav&dcm=douban
# https://fm.douban.com/?from_=shire_top_nav
# https://time.douban.com/?dt_time_source=douban-web_top_nav
# https://market.douban.com/?utm_campaign=douban_top_nav&utm_source=douban&utm_medium=pc_web
# https://book.douban.com
# https://book.douban.com/cart/
# https://read.douban.com/ebooks/?dcs=book-nav&dcm=douban
# https://book.douban.com/annual/2024/?fullscreen=1&dt_from=navigation
# ...

# %%
re.compile('<a.*?href="(.*?)"')
# Out:
# re.compile(r'<a.*?href="(.*?)"', re.UNICODE)

# %%
res_url= re.compile('<a.*?href="(.*?)"')
link = re.findall(res_url, r.text)
link
# Out:
# ['https://accounts.douban.com/passport/login?source=book',
#  'https://www.douban.com/doubanapp/app?channel=top-nav',
#  'https://www.douban.com/doubanapp/app?channel=qipao',
#  'javascript: void 0;',
#  'https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS',
#  'https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android',
#  'https://www.douban.com',
#  'https://book.douban.com',
#  'https://movie.douban.com',
#  'https://music.douban.com',
#  'https://www.douban.com/location',
#  'https://www.douban.com/group',
#  'https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban',
#  'https://fm.douban.com&#47;?from_=shire_top_nav',
#  'https://time.douban.com&#47;?dt_time_source=douban-web_top_nav',
#  'https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web',
#  'https:&#47;&#47;book.douban.com',
#  'https://book.douban.com/cart/',
# ...

# %%
for url in link:
    print(url)
# Out:
# https://accounts.douban.com/passport/login?source=book
# https://www.douban.com/doubanapp/app?channel=top-nav
# https://www.douban.com/doubanapp/app?channel=qipao
# javascript: void 0;
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android
# https://www.douban.com
# https://book.douban.com
# https://movie.douban.com
# https://music.douban.com
# https://www.douban.com/location
# https://www.douban.com/group
# https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban
# https://fm.douban.com&#47;?from_=shire_top_nav
# https://time.douban.com&#47;?dt_time_source=douban-web_top_nav
# https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web
# https:&#47;&#47;book.douban.com
# https://book.douban.com/cart/
# https://read.douban.com/ebooks/?dcs=book-nav&dcm=douban
# ...
