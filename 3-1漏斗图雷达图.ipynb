# %%
import warnings
warnings.filterwarnings('ignore') #当第三方库已经出现新版本，而我们还在使用旧版本时，就会报FutureWarning等

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts.charts import Funnel
from pyecharts import options as opts

labels = ["注册","绑卡","合格投资者","投资", "复投"]
data = [220,160,80, 40, 20]
wf = (
    Funnel()
    .add('转化漏斗',[list(z) for z in zip(labels, data)],
    )  
)

# %%
wf.load_javascript()

# %%
wf.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="957309705f574ae490ef82c60ed75081" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_957309705f574ae490ef82c60ed75081 = echarts.init(
#             document.getElementById('957309705f574ae490ef82c60ed75081'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_957309705f574ae490ef82c60ed75081 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8f6c\u5316\u6f0f\u6597",
#             "data": [
#                 {
#                     "name": "\u6ce8\u518c",
# ...

# %%
from pyecharts.charts import Funnel
from pyecharts import options as opts

labels = ["注册","绑卡", "合格投资者", "投资", "复投"]
data = [220, 160, 80, 40, 20]
wf = (
    Funnel()
    .add(
        '转化漏斗',
        [list(z) for z in zip(labels, data)],
       
        #提示框配置项
        tooltip_opts=opts.TooltipOpts(trigger="item",
                                      formatter="{a} <br/>{b} : {c}"),
        # 标签配置项
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        #图元样式配置项
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff",
                                          border_width=5),
    )
   .set_global_opts(
       legend_opts=opts.LegendOpts(
            pos_top=260,
            pos_left=110,
            orient='vertical')  #设置图例
   )
)
wf.load_javascript()
wf.render_notebook()
#list(z) for z in zip(labels, data)]
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9606ffed0c4841ed87c6f1918435acbb" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_9606ffed0c4841ed87c6f1918435acbb = echarts.init(
#             document.getElementById('9606ffed0c4841ed87c6f1918435acbb'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_9606ffed0c4841ed87c6f1918435acbb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8f6c\u5316\u6f0f\u6597",
#             "data": [
#                 {
#                     "name": "\u6ce8\u518c",
# ...

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts import options as opts
from pyecharts.charts import Radar

v1 = [[4300,10000,28000,35000,50000,19000]]
v2 = [[5000,14000,28000,31000,42000,21000]]
c = (
    Radar()
    .add_schema(
        schema=[#调整雷达各维度的范围大小
            opts.RadarIndicatorItem(name="项目1", max_=6000),
            opts.RadarIndicatorItem(name="项目2", max_=16000),
            opts.RadarIndicatorItem(name="项目3", max_=30000),
            opts.RadarIndicatorItem(name="项目4", max_=38000),
            opts.RadarIndicatorItem(name="项目5", max_=60000),
            opts.RadarIndicatorItem(name="项目6", max_=22000)
        ]
    )
    .add('数据1',v1,color='red')
    .add('数据2',v2,linestyle_opts=opts.LineStyleOpts(color="#00FF00"))
)
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c045ad42b9504c4eba63b3bdfee87e66" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_c045ad42b9504c4eba63b3bdfee87e66 = echarts.init(
#             document.getElementById('c045ad42b9504c4eba63b3bdfee87e66'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_c045ad42b9504c4eba63b3bdfee87e66 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u6570\u636e1",
#             "data": [
#                 [
#                     4300,
#                     10000,
# ...
