# %%
from pyecharts_exporter import display_chart, get_chart_urls

# %%
[f"11月{str(i)}日" for i in range(1, 12)]
# Out:
# ['11月1日',
#  '11月2日',
#  '11月3日',
#  '11月4日',
#  '11月5日',
#  '11月6日',
#  '11月7日',
#  '11月8日',
#  '11月9日',
#  '11月10日',
#  '11月11日']

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

x_data = [f"11月{str(i)}日" for i in range(1, 12)]
y_total = [0, 900, 1245, 1530, 1376, 1376, 1511, 1689, 1856, 1495, 1292]
y_in = [900, 345, 393, "-", "-", 135, 178, 286, "-", "-", "-"]
y_out = ["-", "-", "-", 108, 154, "-", "-", "-", 119, 361, 203]


bar = (
    Bar()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="",
        y_axis=y_total,
        stack="总量",
        itemstyle_opts=opts.ItemStyleOpts(color="rgba(0,0,0,0)"),
        label_opts = opts.LabelOpts(is_show=True),
    )
    .add_yaxis(series_name="收入", y_axis=y_in, stack="总量")
    .add_yaxis(series_name="支出", y_axis=y_out, stack="总量")
    .set_global_opts(
         xaxis_opts=opts.AxisOpts(
            type_="category",
            axislabel_opts=opts.LabelOpts(
                font_size=11,
                interval=1 )),     # 0 表示显示所有标签
        yaxis_opts=opts.AxisOpts(type_="value"))
)


display_chart(bar)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;af71b8c475fc4f69861853c232d9e46e&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_af71b8c475fc4f69861853c232d9e46e = echarts.init(
# ...

# %% [markdown]
# ## K线图基础图示例

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline

data = [
    [2320.26, 2320.26, 2287.3, 2362.94],
    [2300, 2291.3, 2288.26, 2308.38],
    [2295.35, 2346.5, 2295.35, 2345.92],
    [2347.22, 2358.98, 2337.35, 2363.8],
    [2360.75, 2382.48, 2347.89, 2383.76],
    [2383.43, 2385.42, 2371.23, 2391.82],
    [2377.41, 2419.02, 2369.57, 2421.15],
    [2425.92, 2428.15, 2417.58, 2440.38],
    [2411, 2433.13, 2403.3, 2437.42],
    [2432.68, 2334.48, 2427.7, 2441.73],
    [2430.69, 2418.53, 2394.22, 2433.89],
    [2416.62, 2432.4, 2414.4, 2443.03],
    [2441.91, 2421.56, 2418.43, 2444.8],
    [2420.26, 2382.91, 2373.53, 2427.07],
    [2383.49, 2397.18, 2370.61, 2397.94],
    [2378.82, 2325.95, 2309.17, 2378.82],
    [2322.94, 2314.16, 2308.76, 2330.88],
    [2320.62, 2325.82, 2315.01, 2338.78],
    [2313.74, 2293.34, 2289.89, 2340.71],
    [2297.77, 2313.22, 2292.03, 2324.63],
    [2322.32, 2365.59, 2308.92, 2366.16],
    [2364.54, 2359.51, 2330.86, 2369.65],
    [2332.08, 2273.4, 2259.25, 2333.54],
    [2274.81, 2326.31, 2270.1, 2328.14],
    [2333.61, 2347.18, 2321.6, 2351.44],
    [2340.44, 2324.29, 2304.27, 2352.02],
    [2326.42, 2318.61, 2314.59, 2333.67],
    [2314.68, 2310.59, 2296.58, 2320.96],
    [2309.16, 2286.6, 2264.83, 2333.29],
    [2282.17, 2263.97, 2253.25, 2286.33],
    [2255.77, 2270.28, 2253.31, 2276.22],
]

# 创建一个K线图实例
c = (
    Kline()     
    .add_xaxis(["2017/7/{}".format(i+1) for i in range(31)])  # 设置 x 轴的数据，包括7月份所有 31 天，"2017/7/{}".format(i+1)是把数字填入花括号{}的位置
    .add_yaxis("kline", data)    # 设置y轴的数据，这里的 "kline" 是系列名称，data是K线图的数据
 # 设置全局配置项，包括y轴、x轴、标题等配置
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(is_scale=True),   # 设置y轴的刻度是否自适应
        xaxis_opts=opts.AxisOpts(is_scale=True),   # 设置x轴的刻度是否自适应
        title_opts=opts.TitleOpts(title="Kline-基本示例"),  # 设置标题
    )
   # .render("kline_base.html")
)

display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;26f238c4047542149475327683eeb0c7&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_26f238c4047542149475327683eeb0c7 = echarts.init(
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline

data = [
    [2320.26, 2320.26, 2287.3, 2362.94],
    [2300, 2291.3, 2288.26, 2308.38],
    [2295.35, 2346.5, 2295.35, 2345.92],
    [2347.22, 2358.98, 2337.35, 2363.8],
    [2360.75, 2382.48, 2347.89, 2383.76],
    [2383.43, 2385.42, 2371.23, 2391.82],
    [2377.41, 2419.02, 2369.57, 2421.15],
    [2425.92, 2428.15, 2417.58, 2440.38],
    [2411, 2433.13, 2403.3, 2437.42],
    [2432.68, 2334.48, 2427.7, 2441.73],
    [2430.69, 2418.53, 2394.22, 2433.89],
    [2416.62, 2432.4, 2414.4, 2443.03],
    [2441.91, 2421.56, 2418.43, 2444.8],
    [2420.26, 2382.91, 2373.53, 2427.07],
    [2383.49, 2397.18, 2370.61, 2397.94],
    [2378.82, 2325.95, 2309.17, 2378.82],
    [2322.94, 2314.16, 2308.76, 2330.88],
    [2320.62, 2325.82, 2315.01, 2338.78],
    [2313.74, 2293.34, 2289.89, 2340.71],
    [2297.77, 2313.22, 2292.03, 2324.63],
    [2322.32, 2365.59, 2308.92, 2366.16],
    [2364.54, 2359.51, 2330.86, 2369.65],
    [2332.08, 2273.4, 2259.25, 2333.54],
    [2274.81, 2326.31, 2270.1, 2328.14],
    [2333.61, 2347.18, 2321.6, 2351.44],
    [2340.44, 2324.29, 2304.27, 2352.02],
    [2326.42, 2318.61, 2314.59, 2333.67],
    [2314.68, 2310.59, 2296.58, 2320.96],
    [2309.16, 2286.6, 2264.83, 2333.29],
    [2282.17, 2263.97, 2253.25, 2286.33],
    [2255.77, 2270.28, 2253.31, 2276.22],
]


c = (
    Kline()
    .add_xaxis(["2017/7/{}".format(i+1) for i in range(31)])
    .add_yaxis(
        "kline",
        data,
        itemstyle_opts=opts.ItemStyleOpts(
            color="#ec0000",
            color0="#00da3c",
            border_color="#8A0000",
            border_color0="#008F28",
        ),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,   #这里为True表示不包含零刻度
            splitarea_opts=opts.SplitAreaOpts(    # 配置坐标轴的分割区域（即背景中交替的色块）
                is_show=True,     # 是否显示分割区域
                areastyle_opts=opts.AreaStyleOpts(opacity=1)  # 区域样式：透明度设为 1（完全不透明）
            ), 
        ),
        datazoom_opts=[opts.DataZoomOpts(type_="inside")], #区域缩放配置项,组件类型为inside
        title_opts=opts.TitleOpts(title="Kline-ItemStyle"),
    )
   
)
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;318304ee3b8f4615942a4f9c3df4149c&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_318304ee3b8f4615942a4f9c3df4149c = echarts.init(
# ...

# %% [markdown]
# ## K线图区域缩放示例

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline

data = [
    [2320.26, 2320.26, 2287.3, 2362.94],
    [2300, 2291.3, 2288.26, 2308.38],
    [2295.35, 2346.5, 2295.35, 2345.92],
    [2347.22, 2358.98, 2337.35, 2363.8],
    [2360.75, 2382.48, 2347.89, 2383.76],
    [2383.43, 2385.42, 2371.23, 2391.82],
    [2377.41, 2419.02, 2369.57, 2421.15],
    [2425.92, 2428.15, 2417.58, 2440.38],
    [2411, 2433.13, 2403.3, 2437.42],
    [2432.68, 2334.48, 2427.7, 2441.73],
    [2430.69, 2418.53, 2394.22, 2433.89],
    [2416.62, 2432.4, 2414.4, 2443.03],
    [2441.91, 2421.56, 2418.43, 2444.8],
    [2420.26, 2382.91, 2373.53, 2427.07],
    [2383.49, 2397.18, 2370.61, 2397.94],
    [2378.82, 2325.95, 2309.17, 2378.82],
    [2322.94, 2314.16, 2308.76, 2330.88],
    [2320.62, 2325.82, 2315.01, 2338.78],
    [2313.74, 2293.34, 2289.89, 2340.71],
    [2297.77, 2313.22, 2292.03, 2324.63],
    [2322.32, 2365.59, 2308.92, 2366.16],
    [2364.54, 2359.51, 2330.86, 2369.65],
    [2332.08, 2273.4, 2259.25, 2333.54],
    [2274.81, 2326.31, 2270.1, 2328.14],
    [2333.61, 2347.18, 2321.6, 2351.44],
    [2340.44, 2324.29, 2304.27, 2352.02],
    [2326.42, 2318.61, 2314.59, 2333.67],
    [2314.68, 2310.59, 2296.58, 2320.96],
    [2309.16, 2286.6, 2264.83, 2333.29],
    [2282.17, 2263.97, 2253.25, 2286.33],
    [2255.77, 2270.28, 2253.31, 2276.22],
]

c = (
    Kline()
    .add_xaxis(["2017/7/{}".format(i + 1) for i in range(31)])  # 设置 x 轴的数据，包括 7 月份所有 31 天
    .add_yaxis("kline", data)    # 设置 y 轴的数据，其中 "kline" 是系列名称，data 是 K 线图的数据
    .set_global_opts(                 # 设置全局配置项，包括 x 轴与 y 轴的刻度、数据缩放、标题等
        xaxis_opts=opts.AxisOpts(is_scale=True),  # 设置 x 轴的刻度是否自适应
        yaxis_opts=opts.AxisOpts(    # 设置 y轴的刻度、分割区域等
            is_scale=True,      #这里为True表示不包含零刻度
            splitarea_opts=opts.SplitAreaOpts(  # 分割区域选项，包括是否显示、透明度等
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)  
            ),
        ),
        datazoom_opts=[opts.DataZoomOpts( is_show=True, #是否显示组件
                                         type_='slider',  #组件的类型（slider，inside鼠标可以轮滚）
                                         is_realtime=True,   #拖动时，是否实时更新图标
                                          range_start=20,  #开始位置 是%比
                                          pos_bottom="-2%")],   # 数据缩放选项，包括位置等
                                        
        title_opts=opts.TitleOpts(title="Kline-DataZoom-slider-Position"),   # 设置标题
    )
    
)
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;a007692a5e7145718dc85ae352d156c0&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_a007692a5e7145718dc85ae352d156c0 = echarts.init(
# ...

# %%
bar = (
    Bar(init_opts=opts.InitOpts(width='800px', height='500px'))
    .add_xaxis(month)
    .add_yaxis('各月总人数', y_axis=total, stack='人数')
    .add_yaxis('各月入职人数', y_axis=entry, stack="人数")
    .add_yaxis('各月离职人数', y_axis=resign, stack='人数')
    .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=8, color='green', font_weight='bolder')), 
                     yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10, color='blue', font_weight='bolder'))
                    )
)
display_chart(bar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 bar = (
#       2     Bar(init_opts=opts.InitOpts(width='800px', height='500px'))
#       3     .add_xaxis(month)
# ----> 4     .add_yaxis('各月总人数', y_axis=total, stack='人数')
#       5     .add_yaxis('各月入职人数', y_axis=entry, stack="人数")
#       6     .add_yaxis('各月离职人数', y_axis=resign, stack='人数')
#       7     .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=8, color='green', font_weight='bolder')),
#       8                      yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=10, color='blue', font_weight='bolder'))
#       9                     )
#      10 )
#      11 display_chart(bar)
#
# NameError: name 'total' is not defined

# %% [markdown]
# ### 根据瀑布图的特征，它采用绝对值与相对值结合的方式，适用于表达数个特定数值之间的数量变化关系。所以在绘制瀑布图前，要先对数据做一定的改造，能体现绝对值和相对值的关系。
# 每个月的入职人数和离职人数计算的绝对值就是每个月的增加人数或减少人数。如果入职人数大于离职人数，则这个月增加人数为正数、无减少人数（用'-'表示，方便绘图），反之，如果入职人数小于离职人数，则增加人数为'-'，减少人数为正数，入职人数和离职人数相等则增加人数、减少人数都为'-'。
# 每个月的入职人数和总人数，离职人数和总人数计算的相对值是每个月稳定的人数。如果某个月人数增加，则这个月的稳定人数就是月初的总人数，如果某个月人数减少，则这个月的稳定人数就是月初的总人数减掉减少的人数。
# 举例：2023年1月，总人数50，入职0，离职2，则这个月减少2人，稳定人数为50-2=48人。2023年3月，总人数42，入职12，离职6，则这个月增加6人，稳定人数为42人。同理可以推出其他所有月的数据。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

month = [f'2023-0{i}' for i in range(1, 10)] + [f'2023-{i}' for i in range(10, 13)]
fixed = [48, 42, 42, 48, 58, 61, 61, 58, 58, 63, 67, 66]  # 本月稳定人数
add = ['-', '-', 6, 10, 5, '-', 4, '-', 5, 6, '-', '-']  # 增加人数
reduce = [2, 6, '-', '-', '-', 2, '-', 7, '-', '-', 2, 1] # 减少人数
bar = (
    Bar(init_opts=opts.InitOpts(width='800px', height='500px'))
    .add_xaxis(month)
    .add_yaxis(
        series_name="月末实际人数",
        y_axis=fixed,
        stack="人数",
        itemstyle_opts=opts.ItemStyleOpts(color="rgba(240,240,240)"),
    )
    .add_yaxis(series_name="各月增加人数", y_axis=add, stack="人数")
    .add_yaxis(series_name="各月减少人数", y_axis=reduce, stack="人数")
    .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=8, color='green', font_weight='bolder')), 
                 yaxis_opts=opts.AxisOpts(type_="value", axislabel_opts=opts.LabelOpts(font_size=10, color='blue', font_weight='bolder')), 
                    )   
    )
display_chart(bar)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;8e215b9122644d12b83124cf51fc54db&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_8e215b9122644d12b83124cf51fc54db = echarts.init(
# ...

# %%
[f"11月{str(i)}日" for i in range(1, 12)]
# Out:
# ['11月1日',
#  '11月2日',
#  '11月3日',
#  '11月4日',
#  '11月5日',
#  '11月6日',
#  '11月7日',
#  '11月8日',
#  '11月9日',
#  '11月10日',
#  '11月11日']

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

x_data = [f"11月{str(i)}日" for i in range(1, 12)]
y_total = [0, 900, 1245, 1530, 1376, 1376, 1511, 1689, 1856, 1495, 1292]
y_in = [900, 345, 393, "-", "-", 135, 178, 286, "-", "-", "-"]
y_out = ["-", "-", "-", 108, 154, "-", "-", "-", 119, 361, 203]


bar = (
    Bar()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="",
        y_axis=y_total,
        stack="总量",
        itemstyle_opts=opts.ItemStyleOpts(color="rgba(0,0,0,0)"),
        label_opts = opts.LabelOpts(is_show=True),
    )
    .add_yaxis(series_name="收入", y_axis=y_in, stack="总量")
    .add_yaxis(series_name="支出", y_axis=y_out, stack="总量")
    .set_global_opts(
         xaxis_opts=opts.AxisOpts(
            type_="category",
            axislabel_opts=opts.LabelOpts(
                font_size=11,
                interval=0 )),     # 0 表示显示所有标签
        yaxis_opts=opts.AxisOpts(type_="value"))
)
display_chart(bar)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;864da9c123ec4cb899a75819c5f7318d&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_864da9c123ec4cb899a75819c5f7318d = echarts.init(
# ...

# %% [markdown]
# ## 上机实践07

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# 1. 定义 X 轴标签
x_data = ["产品销售收入", "销售费用", "销售成本", "增值税", "城建税", "教育费附加", "其他附加税费", "产品销售利润"]

# 2. 定义核心数据 (以下数据严格对应您的图片数值)

# 关键：y_total 是“透明底柱”的高度，它是为了让上面的绿柱子和蓝柱子悬浮在正确的位置
# 计算逻辑：
# 收入(1700)下方是0 
# 减去销售费用(151)后，剩余高度是 1700 - 151 = 1549
# 减去销售成本(620)后，剩余高度是 1549 - 620 = 929
# ... 依此类推，直到最后利润 487
y_total = [
    0,          # 产品销售收入 (柱子在0以上)
    1549,       # 销售费用 (-151，柱子顶在1549，底在1700)
    929,        # 销售成本 (-620，柱子顶在929，底在1549)
    640,        # 增值税 (-289，柱子顶在640，底在929)
    555,        # 城建税 (-85，柱子顶在555，底在640)
    504,        # 教育费附加 (-51，柱子顶在504，底在555)
    487,        # 其他附加税费 (-17，柱子顶在487，底在504)
    0           # 产品销售利润 (最终结果，柱子顶在487，底在0)
]

# y_in：蓝柱子（收入/利润），正数会在底部向上生长
y_in = [
    1700,    # 产品销售收入
    "-",     # 销售费用是支出，不填这里
    "-",     # 销售成本
    "-",     # 增值税
    "-",     # 城建税
    "-",     # 教育费附加
    "-",     # 其他附加税费
    487      # 产品销售利润
]

# y_out：绿柱子（支出/成本），负数会从“透明底柱”向下生长
# 注意：在 pyecharts 中如果是负数，图表会自动向下画，但配合 stack，我们可以用正数来表示向下延伸的长度
y_out = [
    "-",     # 产品销售收入是收入
    151,     # 销售费用
    620,     # 销售成本
    289,     # 增值税
    85,      # 城建税
    51,      # 教育费附加
    17,      # 其他附加税费
    "-"      # 产品销售利润
]

# 3. 创建图表
bar = (
    Bar()
    .add_xaxis(xaxis_data=x_data)
    # 第一层：透明底柱（必须放在第一位，stack名称设为"总量"）
    .add_yaxis(
        series_name="",
        y_axis=y_total,
        stack="总量",
        itemstyle_opts=opts.ItemStyleOpts(color="rgba(0,0,0,0)"),  # 完全透明
        label_opts=opts.LabelOpts(is_show=False),  # 不显示标签
    )
    # 第二层：收入（蓝色）
    .add_yaxis(
        series_name="收入",
        y_axis=y_in,
        stack="总量",
        itemstyle_opts=opts.ItemStyleOpts(color="#5470c6"),  # 蓝色
        label_opts=opts.LabelOpts(is_show=True, position="inside"),  # 数值显示在内部
    )
    # 第三层：支出（绿色）
    .add_yaxis(
        series_name="支出",
        y_axis=y_out,
        stack="总量",
        itemstyle_opts=opts.ItemStyleOpts(color="#91cc75"),  # 绿色
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
    )
    # 4. 全局配置
    .set_global_opts(
        title_opts=opts.TitleOpts(title="某公司2023年产品销售利润瀑布图", pos_left="center"),
        legend_opts=opts.LegendOpts(pos_top="5%"),
        yaxis_opts=opts.AxisOpts(
            name="万元",
            splitline_opts=opts.SplitLineOpts(is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=0.3))
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axislabel_opts=opts.LabelOpts(font_size=12, interval=0)  # interval=0 强制显示所有标签
        ),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="shadow")
    )
)

display_chart(bar)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;50451ed3da2044c5b13e4875bb8665ca&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_50451ed3da2044c5b13e4875bb8665ca = echarts.init(
# ...

# %%
import pandas as pd
from pyecharts.charts import Kline
from pyecharts import options as opts

# 1. 读取 CSV 数据
# 注意：请确保 AXP.csv 文件与代码在同一目录下
df = pd.read_csv('./data/AXP.csv')

# 2. 提取前100条数据
df_100 = df.head(100)

# 3. 准备 K线图数据
# K线图需要的数据格式为：[开盘, 收盘, 最低, 最高]
# 注意：pyecharts 的 Kline 数据顺序是 [Open, Close, Low, High]
k_data = []
for index, row in df_100.iterrows():
    # 提取并转换为浮点数，避免字符串类型问题
    open_price = float(row['Open'])
    close_price = float(row['Close'])
    low_price = float(row['Low'])
    high_price = float(row['High'])
    k_data.append([open_price, close_price, low_price, high_price])

# 4. 准备 X 轴标签（日期）
x_axis_data = df_100['Date'].tolist()

# 5. 创建 K线图
c = (
    Kline()
    .add_xaxis(xaxis_data=x_axis_data)
    .add_yaxis(
        series_name="AXP",
        y_axis=k_data,
        # 设置K线颜色：阳线（收盘>开盘）为红色，阴线为绿色
        itemstyle_opts=opts.ItemStyleOpts(
            color="#ec0000",      # 阳线（涨）填充色
            color0="#00da3c",     # 阴线（跌）填充色
            border_color="#8A0000",    # 阳线边框色
            border_color0="#008F28",   # 阴线边框色
        )
    )
    .set_global_opts(
        # (3) 主标题
        title_opts=opts.TitleOpts(
            title="AXP股票数据K线图",
            pos_left="center"
        ),
        # 设置 X 轴（日期）标签旋转，防止重叠
        xaxis_opts=opts.AxisOpts(
            type_="category",
            is_scale=True,
            axislabel_opts=opts.LabelOpts(rotate=45),
            splitline_opts=opts.SplitLineOpts(is_show=False)
        ),
        # 设置 Y 轴标签
        yaxis_opts=opts.AxisOpts(
            type_="value",
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True,
                areastyle_opts=opts.AreaStyleOpts(opacity=0.1)
            )
        ),
        # (4) 区域缩放配置 - inside 类型
        datazoom_opts=[
            opts.DataZoomOpts(
                is_show=False,      # 不显示外部滚动条
                type_="inside",     # 设置为内部缩放（鼠标滚轮/拖拽）
                xaxis_index=[0],    # 应用于 X 轴
                range_start=0,      # 初始显示范围开始
                range_end=100       # 初始显示范围结束
            )
        ],
        # 鼠标悬停提示
        tooltip_opts=opts.TooltipOpts(
            trigger="axis",
            axis_pointer_type="cross",
            background_color="rgba(255, 255, 255, 0.9)",
            border_width=1,
            border_color="#ccc",
            textstyle_opts=opts.TextStyleOpts(color="#333")
        ),
        # 图例
        legend_opts=opts.LegendOpts(is_show=True, pos_top="5%")
    )
)

display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;144bee66729e4cacb72f517dd866e7cc&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_144bee66729e4cacb72f517dd866e7cc = echarts.init(
# ...
