# %%
import warnings
warnings.filterwarnings('ignore') #当第三方库已经出现新版本，而我们还在使用旧版本时，就会报FutureWarning等

# %%
from pyecharts_exporter import display_chart, get_chart_urls
from pyecharts.globals import CurrentConfig, ThemeType

from pyecharts.charts import Funnel
from pyecharts import options as opts

labels = ["注册","绑卡","合格投资者","投资", "复投"]
data = [220,160,80, 40, 20]
wf = (
    Funnel(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add('转化漏斗',[list(z) for z in zip(labels, data)],
    )  
)

# %%
display_chart(wf)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://fastly.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;2b2d9d1c72984655805543d5416b69c0&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_2b2d9d1c72984655805543d5416b69c0 = echarts.init(
#             document.getElementById(&#x27;2b2d9d1c72984655805543d5416b69c0&#x27;), &#x27;light&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_2b2d9d1c72984655805543d5416b69c0 = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;funnel&quot;,
#             &quot;name&quot;: &quot;\u8f6c\u5316\u6f0f\u6597&quot;,
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6ce8\u518c&quot;,
#                     &quot;value&quot;: 220
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u7ed1\u5361&quot;,
#                     &quot;value&quot;: 160
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5408\u683c\u6295\u8d44\u8005&quot;,
#                     &quot;value&quot;: 80
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u6295\u8d44&quot;,
#                     &quot;value&quot;: 40
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u590d\u6295&quot;,
#                     &quot;value&quot;: 20
#                 }
#             ],
#             &quot;min&quot;: 0,
#             &quot;max&quot;: 100,
#             &quot;minSize&quot;: &quot;0%&quot;,
#             &quot;maxSize&quot;: &quot;100%&quot;,
#             &quot;orient&quot;: &quot;vertical&quot;,
#             &quot;sort&quot;: &quot;descending&quot;,
#             &quot;gap&quot;: 0,
#             &quot;legendHoverLink&quot;: true,
#             &quot;funnelAlign&quot;: &quot;center&quot;,
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;selectedMode&quot;: false,
#             &quot;zlevel&quot;: 0,
#             &quot;z&quot;: 2
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6295\u8d44&quot;,
#                 &quot;\u7ed1\u5361&quot;,
#                 &quot;\u6ce8\u518c&quot;,
#                 &quot;\u590d\u6295&quot;,
#                 &quot;\u5408\u683c\u6295\u8d44\u8005&quot;
#             ],
#             &quot;selected&quot;: {}
#         }
#     ],
#     &quot;tooltip&quot;: {
#         &quot;show&quot;: true,
#         &quot;trigger&quot;: &quot;item&quot;,
#         &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#         &quot;axisPointer&quot;: {
#             &quot;type&quot;: &quot;line&quot;
#         },
#         &quot;showContent&quot;: true,
#         &quot;alwaysShowContent&quot;: false,
#         &quot;showDelay&quot;: 0,
#         &quot;hideDelay&quot;: 100,
#         &quot;enterable&quot;: false,
#         &quot;confine&quot;: false,
#         &quot;appendToBody&quot;: false,
#         &quot;transitionDuration&quot;: 0.4,
#         &quot;displayTransition&quot;: true,
#         &quot;textStyle&quot;: {
#             &quot;fontSize&quot;: 14,
#             &quot;richInheritPlainLabel&quot;: true
#         },
#         &quot;borderWidth&quot;: 0,
#         &quot;padding&quot;: 5,
#         &quot;order&quot;: &quot;seriesAsc&quot;
#     }
# };
#         chart_2b2d9d1c72984655805543d5416b69c0.setOption(option_2b2d9d1c72984655805543d5416b69c0);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
#
#         &lt;/body&gt;
#         &lt;/html&gt;
#         "
#                 width="900px" height="500px"
#                 frameborder="0" scrolling="no" sandbox="allow-scripts allow-same-origin allow-downloads">
#         </iframe>

# %%
from pyecharts.charts import Funnel
from pyecharts import options as opts

labels = ["注册","绑卡", "合格投资者", "投资", "复投"]
data = [220, 160, 80, 40, 20]
wf = (
    Funnel(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add(
        '转化漏斗',
        [list(z) for z in zip(labels, data)],
       
        #提示框配置项
        tooltip_opts=opts.TooltipOpts(trigger="item",
                                      formatter="{a} <br/>{b} : {c}"),
        # 标签配置项
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        #图元样式配置项
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff",
                                          border_width=5),
    )
   .set_global_opts(
       legend_opts=opts.LegendOpts(
            pos_top=260,
            pos_left=110,
            orient='vertical')  #设置图例
   )
)
display_chart(wf)
#list(z) for z in zip(labels, data)]
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://fastly.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;1c90993917fd4b98840de3ca4fe39828&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_1c90993917fd4b98840de3ca4fe39828 = echarts.init(
#             document.getElementById(&#x27;1c90993917fd4b98840de3ca4fe39828&#x27;), &#x27;light&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_1c90993917fd4b98840de3ca4fe39828 = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;funnel&quot;,
#             &quot;name&quot;: &quot;\u8f6c\u5316\u6f0f\u6597&quot;,
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6ce8\u518c&quot;,
#                     &quot;value&quot;: 220
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u7ed1\u5361&quot;,
#                     &quot;value&quot;: 160
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5408\u683c\u6295\u8d44\u8005&quot;,
#                     &quot;value&quot;: 80
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u6295\u8d44&quot;,
#                     &quot;value&quot;: 40
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u590d\u6295&quot;,
#                     &quot;value&quot;: 20
#                 }
#             ],
#             &quot;min&quot;: 0,
#             &quot;max&quot;: 100,
#             &quot;minSize&quot;: &quot;0%&quot;,
#             &quot;maxSize&quot;: &quot;100%&quot;,
#             &quot;orient&quot;: &quot;vertical&quot;,
#             &quot;sort&quot;: &quot;descending&quot;,
#             &quot;gap&quot;: 0,
#             &quot;legendHoverLink&quot;: true,
#             &quot;funnelAlign&quot;: &quot;center&quot;,
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;position&quot;: &quot;inside&quot;,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;tooltip&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;trigger&quot;: &quot;item&quot;,
#                 &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#                 &quot;axisPointer&quot;: {
#                     &quot;type&quot;: &quot;line&quot;
#                 },
#                 &quot;showContent&quot;: true,
#                 &quot;alwaysShowContent&quot;: false,
#                 &quot;showDelay&quot;: 0,
#                 &quot;hideDelay&quot;: 100,
#                 &quot;enterable&quot;: false,
#                 &quot;confine&quot;: false,
#                 &quot;appendToBody&quot;: false,
#                 &quot;transitionDuration&quot;: 0.4,
#                 &quot;displayTransition&quot;: true,
#                 &quot;formatter&quot;: &quot;{a} &lt;br/&gt;{b} : {c}&quot;,
#                 &quot;textStyle&quot;: {
#                     &quot;fontSize&quot;: 14,
#                     &quot;richInheritPlainLabel&quot;: true
#                 },
#                 &quot;borderWidth&quot;: 0,
#                 &quot;padding&quot;: 5,
#                 &quot;order&quot;: &quot;seriesAsc&quot;
#             },
#             &quot;itemStyle&quot;: {
#                 &quot;borderColor&quot;: &quot;#fff&quot;,
#                 &quot;borderWidth&quot;: 5
#             },
#             &quot;selectedMode&quot;: false,
#             &quot;zlevel&quot;: 0,
#             &quot;z&quot;: 2
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6295\u8d44&quot;,
#                 &quot;\u7ed1\u5361&quot;,
#                 &quot;\u6ce8\u518c&quot;,
#                 &quot;\u590d\u6295&quot;,
#                 &quot;\u5408\u683c\u6295\u8d44\u8005&quot;
#             ],
#             &quot;selected&quot;: {},
#             &quot;show&quot;: true,
#             &quot;left&quot;: 110,
#             &quot;top&quot;: 260,
#             &quot;orient&quot;: &quot;vertical&quot;,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;itemWidth&quot;: 25,
#             &quot;itemHeight&quot;: 14,
#             &quot;backgroundColor&quot;: &quot;transparent&quot;,
#             &quot;borderColor&quot;: &quot;#ccc&quot;,
#             &quot;borderRadius&quot;: 0,
#             &quot;pageButtonItemGap&quot;: 5,
#             &quot;pageButtonPosition&quot;: &quot;end&quot;,
#             &quot;pageFormatter&quot;: &quot;{current}/{total}&quot;,
#             &quot;pageIconColor&quot;: &quot;#2f4554&quot;,
#             &quot;pageIconInactiveColor&quot;: &quot;#aaa&quot;,
#             &quot;pageIconSize&quot;: 15,
#             &quot;animationDurationUpdate&quot;: 800,
#             &quot;selector&quot;: false,
#             &quot;selectorPosition&quot;: &quot;auto&quot;,
#             &quot;selectorItemGap&quot;: 7,
#             &quot;selectorButtonGap&quot;: 10,
#             &quot;triggerEvent&quot;: false
#         }
#     ],
#     &quot;tooltip&quot;: {
#         &quot;show&quot;: true,
#         &quot;trigger&quot;: &quot;item&quot;,
#         &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#         &quot;axisPointer&quot;: {
#             &quot;type&quot;: &quot;line&quot;
#         },
#         &quot;showContent&quot;: true,
#         &quot;alwaysShowContent&quot;: false,
#         &quot;showDelay&quot;: 0,
#         &quot;hideDelay&quot;: 100,
#         &quot;enterable&quot;: false,
#         &quot;confine&quot;: false,
#         &quot;appendToBody&quot;: false,
#         &quot;transitionDuration&quot;: 0.4,
#         &quot;displayTransition&quot;: true,
#         &quot;textStyle&quot;: {
#             &quot;fontSize&quot;: 14,
#             &quot;richInheritPlainLabel&quot;: true
#         },
#         &quot;borderWidth&quot;: 0,
#         &quot;padding&quot;: 5,
#         &quot;order&quot;: &quot;seriesAsc&quot;
#     },
#     &quot;title&quot;: [
#         {
#             &quot;show&quot;: true,
#             &quot;target&quot;: &quot;blank&quot;,
#             &quot;subtarget&quot;: &quot;blank&quot;,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;textAlign&quot;: &quot;auto&quot;,
#             &quot;textVerticalAlign&quot;: &quot;auto&quot;,
#             &quot;triggerEvent&quot;: false
#         }
#     ]
# };
#         chart_1c90993917fd4b98840de3ca4fe39828.setOption(option_1c90993917fd4b98840de3ca4fe39828);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
#
#         &lt;/body&gt;
#         &lt;/html&gt;
#         "
#                 width="900px" height="500px"
#                 frameborder="0" scrolling="no" sandbox="allow-scripts allow-same-origin allow-downloads">
#         </iframe>

# %%
from pyecharts import options as opts
from pyecharts.charts import Radar

v1 = [[4300,10000,28000,35000,50000,19000]]
v2 = [[5000,14000,28000,31000,42000,21000]]
c = (
    Radar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_schema(
        schema=[#调整雷达各维度的范围大小
            opts.RadarIndicatorItem(name="项目1", max_=6000),
            opts.RadarIndicatorItem(name="项目2", max_=16000),
            opts.RadarIndicatorItem(name="项目3", max_=30000),
            opts.RadarIndicatorItem(name="项目4", max_=38000),
            opts.RadarIndicatorItem(name="项目5", max_=60000),
            opts.RadarIndicatorItem(name="项目6", max_=22000)
        ]
    )
    .add('数据1',v1,color='red')
    .add('数据2',v2,linestyle_opts=opts.LineStyleOpts(color="#00FF00"))
)
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://fastly.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;91daf3ec9dfb46df9990ba9abefbb279&quot; class=&quot;chart-container&quot; style=&quot;width:900px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_91daf3ec9dfb46df9990ba9abefbb279 = echarts.init(
#             document.getElementById(&#x27;91daf3ec9dfb46df9990ba9abefbb279&#x27;), &#x27;light&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_91daf3ec9dfb46df9990ba9abefbb279 = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;radar&quot;,
#             &quot;name&quot;: &quot;\u6570\u636e1&quot;,
#             &quot;data&quot;: [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;selectedMode&quot;: false,
#             &quot;zlevel&quot;: 0,
#             &quot;z&quot;: 2,
#             &quot;itemStyle&quot;: {
#                 &quot;normal&quot;: {
#                     &quot;color&quot;: &quot;red&quot;
#                 }
#             },
#             &quot;lineStyle&quot;: {
#                 &quot;show&quot;: false
#             },
#             &quot;areaStyle&quot;: {
#                 &quot;opacity&quot;: 0
#             }
#         },
#         {
#             &quot;type&quot;: &quot;radar&quot;,
#             &quot;name&quot;: &quot;\u6570\u636e2&quot;,
#             &quot;data&quot;: [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;selectedMode&quot;: false,
#             &quot;zlevel&quot;: 0,
#             &quot;z&quot;: 2,
#             &quot;itemStyle&quot;: {
#                 &quot;normal&quot;: {}
#             },
#             &quot;lineStyle&quot;: {
#                 &quot;show&quot;: false,
#                 &quot;color&quot;: &quot;#00FF00&quot;
#             },
#             &quot;areaStyle&quot;: {
#                 &quot;opacity&quot;: 0
#             }
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6570\u636e1&quot;,
#                 &quot;\u6570\u636e2&quot;
#             ],
#             &quot;selected&quot;: {}
#         }
#     ],
#     &quot;tooltip&quot;: {
#         &quot;show&quot;: true,
#         &quot;trigger&quot;: &quot;item&quot;,
#         &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#         &quot;axisPointer&quot;: {
#             &quot;type&quot;: &quot;line&quot;
#         },
#         &quot;showContent&quot;: true,
#         &quot;alwaysShowContent&quot;: false,
#         &quot;showDelay&quot;: 0,
#         &quot;hideDelay&quot;: 100,
#         &quot;enterable&quot;: false,
#         &quot;confine&quot;: false,
#         &quot;appendToBody&quot;: false,
#         &quot;transitionDuration&quot;: 0.4,
#         &quot;displayTransition&quot;: true,
#         &quot;textStyle&quot;: {
#             &quot;fontSize&quot;: 14,
#             &quot;richInheritPlainLabel&quot;: true
#         },
#         &quot;borderWidth&quot;: 0,
#         &quot;padding&quot;: 5,
#         &quot;order&quot;: &quot;seriesAsc&quot;
#     },
#     &quot;radar&quot;: [
#         {
#             &quot;indicator&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee1&quot;,
#                     &quot;max&quot;: 6000
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee2&quot;,
#                     &quot;max&quot;: 16000
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee3&quot;,
#                     &quot;max&quot;: 30000
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee4&quot;,
#                     &quot;max&quot;: 38000
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee5&quot;,
#                     &quot;max&quot;: 60000
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u9879\u76ee6&quot;,
#                     &quot;max&quot;: 22000
#                 }
#             ],
#             &quot;startAngle&quot;: 90,
#             &quot;name&quot;: {
#                 &quot;textStyle&quot;: {
#                     &quot;richInheritPlainLabel&quot;: true
#                 }
#             },
#             &quot;splitLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;lineStyle&quot;: {
#                     &quot;show&quot;: false
#                 }
#             },
#             &quot;splitArea&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;areaStyle&quot;: {
#                     &quot;opacity&quot;: 0
#                 }
#             },
#             &quot;axisLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;onZero&quot;: true,
#                 &quot;onZeroAxisIndex&quot;: 0
#             }
#         }
#     ]
# };
#         chart_91daf3ec9dfb46df9990ba9abefbb279.setOption(option_91daf3ec9dfb46df9990ba9abefbb279);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
#
#         &lt;/body&gt;
#         &lt;/html&gt;
#         "
#                 width="900px" height="500px"
#                 frameborder="0" scrolling="no" sandbox="allow-scripts allow-same-origin allow-downloads">
#         </iframe>
