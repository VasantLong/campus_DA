# %%
from pyecharts_exporter import display_chart, get_chart_urls

# %%
from pyecharts import options as opts    
from pyecharts.charts import Page, Pie
L1=['教授','副教授','讲师','助教','其他']
num  = [20,30,10,12,8]
#绘制饼图
c = (
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add(series_name="",data_pair=[list(z) for z in zip(L1,num)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类别比例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

#c.load_javascript()
#c.render_notebook()
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;2b4386524b484cd89e88044415651d5a&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_2b4386524b484cd89e88044415651d5a = echarts.init(
#             document.getElementById(&#x27;2b4386524b484cd89e88044415651d5a&#x27;), &#x27;white&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_2b4386524b484cd89e88044415651d5a = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;pie&quot;,
#             &quot;colorBy&quot;: &quot;data&quot;,
#             &quot;legendHoverLink&quot;: true,
#             &quot;selectedMode&quot;: false,
#             &quot;selectedOffset&quot;: 10,
#             &quot;clockwise&quot;: true,
#             &quot;startAngle&quot;: 90,
#             &quot;minAngle&quot;: 0,
#             &quot;minShowLabelAngle&quot;: 0,
#             &quot;avoidLabelOverlap&quot;: true,
#             &quot;stillShowZeroSum&quot;: true,
#             &quot;percentPrecision&quot;: 2,
#             &quot;showEmptyCircle&quot;: true,
#             &quot;emptyCircleStyle&quot;: {
#                 &quot;color&quot;: &quot;lightgray&quot;,
#                 &quot;borderColor&quot;: &quot;#000&quot;,
#                 &quot;borderWidth&quot;: 0,
#                 &quot;borderType&quot;: &quot;solid&quot;,
#                 &quot;borderDashOffset&quot;: 0,
#                 &quot;borderCap&quot;: &quot;butt&quot;,
#                 &quot;borderJoin&quot;: &quot;bevel&quot;,
#                 &quot;borderMiterLimit&quot;: 10,
#                 &quot;opacity&quot;: 1
#             },
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6559\u6388&quot;,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u526f\u6559\u6388&quot;,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u8bb2\u5e08&quot;,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u52a9\u6559&quot;,
#                     &quot;value&quot;: 12
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5176\u4ed6&quot;,
#                     &quot;value&quot;: 8
#                 }
#             ],
#             &quot;radius&quot;: [
#                 &quot;0%&quot;,
#                 &quot;75%&quot;
#             ],
#             &quot;center&quot;: [
#                 &quot;50%&quot;,
#                 &quot;50%&quot;
#             ],
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;formatter&quot;: &quot;{b}: {c}&quot;,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;labelLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;showAbove&quot;: false,
#                 &quot;length&quot;: 15,
#                 &quot;length2&quot;: 15,
#                 &quot;smooth&quot;: false,
#                 &quot;minTurnAngle&quot;: 90,
#                 &quot;maxSurfaceAngle&quot;: 90
#             },
#             &quot;rippleEffect&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;brushType&quot;: &quot;stroke&quot;,
#                 &quot;scale&quot;: 2.5,
#                 &quot;period&quot;: 4
#             }
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6559\u6388&quot;,
#                 &quot;\u526f\u6559\u6388&quot;,
#                 &quot;\u8bb2\u5e08&quot;,
#                 &quot;\u52a9\u6559&quot;,
#                 &quot;\u5176\u4ed6&quot;
#             ],
#             &quot;selected&quot;: {},
#             &quot;show&quot;: true,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;itemWidth&quot;: 25,
#             &quot;itemHeight&quot;: 14,
#             &quot;backgroundColor&quot;: &quot;transparent&quot;,
#             &quot;borderColor&quot;: &quot;#ccc&quot;,
#             &quot;borderRadius&quot;: 0,
#             &quot;pageButtonItemGap&quot;: 5,
#             &quot;pageButtonPosition&quot;: &quot;end&quot;,
#             &quot;pageFormatter&quot;: &quot;{current}/{total}&quot;,
#             &quot;pageIconColor&quot;: &quot;#2f4554&quot;,
#             &quot;pageIconInactiveColor&quot;: &quot;#aaa&quot;,
#             &quot;pageIconSize&quot;: 15,
#             &quot;animationDurationUpdate&quot;: 800,
#             &quot;selector&quot;: false,
#             &quot;selectorPosition&quot;: &quot;auto&quot;,
#             &quot;selectorItemGap&quot;: 7,
#             &quot;selectorButtonGap&quot;: 10,
#             &quot;triggerEvent&quot;: false
#         }
#     ],
#     &quot;tooltip&quot;: {
#         &quot;show&quot;: true,
#         &quot;trigger&quot;: &quot;item&quot;,
#         &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#         &quot;axisPointer&quot;: {
#             &quot;type&quot;: &quot;line&quot;
#         },
#         &quot;showContent&quot;: true,
#         &quot;alwaysShowContent&quot;: false,
#         &quot;showDelay&quot;: 0,
#         &quot;hideDelay&quot;: 100,
#         &quot;enterable&quot;: false,
#         &quot;confine&quot;: false,
#         &quot;appendToBody&quot;: false,
#         &quot;transitionDuration&quot;: 0.4,
#         &quot;displayTransition&quot;: true,
#         &quot;textStyle&quot;: {
#             &quot;fontSize&quot;: 14,
#             &quot;richInheritPlainLabel&quot;: true
#         },
#         &quot;borderWidth&quot;: 0,
#         &quot;padding&quot;: 5,
#         &quot;order&quot;: &quot;seriesAsc&quot;
#     },
#     &quot;title&quot;: [
#         {
#             &quot;show&quot;: true,
#             &quot;text&quot;: &quot;Pie-\u804c\u79f0\u7c7b\u522b\u6bd4\u4f8b&quot;,
#             &quot;target&quot;: &quot;blank&quot;,
#             &quot;subtarget&quot;: &quot;blank&quot;,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;textAlign&quot;: &quot;auto&quot;,
#             &quot;textVerticalAlign&quot;: &quot;auto&quot;,
#             &quot;triggerEvent&quot;: false
#         }
#     ]
# };
#         chart_2b4386524b484cd89e88044415651d5a.setOption(option_2b4386524b484cd89e88044415651d5a);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
#
#         &lt;/body&gt;
#         &lt;/html&gt;
#         "
#                 width="800px" height="500px"
#                 frameborder="0" scrolling="no" sandbox="allow-scripts allow-same-origin allow-downloads">
#         </iframe>

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = (
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add("",[list(z) for z in zip(wd, num)],radius = ["40%", "75%"]) # 圆环的粗细和大小  
    .set_global_opts( 
        title_opts=opts.TitleOpts(title="Pie-Radius"),
        legend_opts=opts.LegendOpts( orient="vertical", pos_top="5%", pos_left="2%" )
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;6062e8c37e4948eaa033cc4b227990c6&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_6062e8c37e4948eaa033cc4b227990c6 = echarts.init(
#             document.getElementById(&#x27;6062e8c37e4948eaa033cc4b227990c6&#x27;), &#x27;white&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_6062e8c37e4948eaa033cc4b227990c6 = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;pie&quot;,
#             &quot;colorBy&quot;: &quot;data&quot;,
#             &quot;legendHoverLink&quot;: true,
#             &quot;selectedMode&quot;: false,
#             &quot;selectedOffset&quot;: 10,
#             &quot;clockwise&quot;: true,
#             &quot;startAngle&quot;: 90,
#             &quot;minAngle&quot;: 0,
#             &quot;minShowLabelAngle&quot;: 0,
#             &quot;avoidLabelOverlap&quot;: true,
#             &quot;stillShowZeroSum&quot;: true,
#             &quot;percentPrecision&quot;: 2,
#             &quot;showEmptyCircle&quot;: true,
#             &quot;emptyCircleStyle&quot;: {
#                 &quot;color&quot;: &quot;lightgray&quot;,
#                 &quot;borderColor&quot;: &quot;#000&quot;,
#                 &quot;borderWidth&quot;: 0,
#                 &quot;borderType&quot;: &quot;solid&quot;,
#                 &quot;borderDashOffset&quot;: 0,
#                 &quot;borderCap&quot;: &quot;butt&quot;,
#                 &quot;borderJoin&quot;: &quot;bevel&quot;,
#                 &quot;borderMiterLimit&quot;: 10,
#                 &quot;opacity&quot;: 1
#             },
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6559\u6388&quot;,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u526f\u6559\u6388&quot;,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u8bb2\u5e08&quot;,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u52a9\u6559&quot;,
#                     &quot;value&quot;: 12
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5176\u4ed6&quot;,
#                     &quot;value&quot;: 8
#                 }
#             ],
#             &quot;radius&quot;: [
#                 &quot;40%&quot;,
#                 &quot;75%&quot;
#             ],
#             &quot;center&quot;: [
#                 &quot;50%&quot;,
#                 &quot;50%&quot;
#             ],
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;formatter&quot;: &quot;{b}: {c}&quot;,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;labelLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;showAbove&quot;: false,
#                 &quot;length&quot;: 15,
#                 &quot;length2&quot;: 15,
#                 &quot;smooth&quot;: false,
#                 &quot;minTurnAngle&quot;: 90,
#                 &quot;maxSurfaceAngle&quot;: 90
#             },
#             &quot;rippleEffect&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;brushType&quot;: &quot;stroke&quot;,
#                 &quot;scale&quot;: 2.5,
#                 &quot;period&quot;: 4
#             }
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6559\u6388&quot;,
#                 &quot;\u526f\u6559\u6388&quot;,
#                 &quot;\u8bb2\u5e08&quot;,
#                 &quot;\u52a9\u6559&quot;,
#                 &quot;\u5176\u4ed6&quot;
#             ],
#             &quot;selected&quot;: {},
#             &quot;show&quot;: true,
#             &quot;left&quot;: &quot;2%&quot;,
#             &quot;top&quot;: &quot;5%&quot;,
#             &quot;orient&quot;: &quot;vertical&quot;,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;itemWidth&quot;: 25,
#             &quot;itemHeight&quot;: 14,
#             &quot;backgroundColor&quot;: &quot;transparent&quot;,
#             &quot;borderColor&quot;: &quot;#ccc&quot;,
#             &quot;borderRadius&quot;: 0,
#             &quot;pageButtonItemGap&quot;: 5,
#             &quot;pageButtonPosition&quot;: &quot;end&quot;,
#             &quot;pageFormatter&quot;: &quot;{current}/{total}&quot;,
#             &quot;pageIconColor&quot;: &quot;#2f4554&quot;,
#             &quot;pageIconInactiveColor&quot;: &quot;#aaa&quot;,
#             &quot;pageIconSize&quot;: 15,
#             &quot;animationDurationUpdate&quot;: 800,
#             &quot;selector&quot;: false,
#             &quot;selectorPosition&quot;: &quot;auto&quot;,
#             &quot;selectorItemGap&quot;: 7,
#             &quot;selectorButtonGap&quot;: 10,
#             &quot;triggerEvent&quot;: false
#         }
#     ],
#     &quot;tooltip&quot;: {
#         &quot;show&quot;: true,
#         &quot;trigger&quot;: &quot;item&quot;,
#         &quot;triggerOn&quot;: &quot;mousemove|click&quot;,
#         &quot;axisPointer&quot;: {
#             &quot;type&quot;: &quot;line&quot;
#         },
#         &quot;showContent&quot;: true,
#         &quot;alwaysShowContent&quot;: false,
#         &quot;showDelay&quot;: 0,
#         &quot;hideDelay&quot;: 100,
#         &quot;enterable&quot;: false,
#         &quot;confine&quot;: false,
#         &quot;appendToBody&quot;: false,
#         &quot;transitionDuration&quot;: 0.4,
#         &quot;displayTransition&quot;: true,
#         &quot;textStyle&quot;: {
#             &quot;fontSize&quot;: 14,
#             &quot;richInheritPlainLabel&quot;: true
#         },
#         &quot;borderWidth&quot;: 0,
#         &quot;padding&quot;: 5,
#         &quot;order&quot;: &quot;seriesAsc&quot;
#     },
#     &quot;title&quot;: [
#         {
#             &quot;show&quot;: true,
#             &quot;text&quot;: &quot;Pie-Radius&quot;,
#             &quot;target&quot;: &quot;blank&quot;,
#             &quot;subtarget&quot;: &quot;blank&quot;,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;textAlign&quot;: &quot;auto&quot;,
#             &quot;textVerticalAlign&quot;: &quot;auto&quot;,
#             &quot;triggerEvent&quot;: false
#         }
#     ]
# };
#         chart_6062e8c37e4948eaa033cc4b227990c6.setOption(option_6062e8c37e4948eaa033cc4b227990c6);
#     &lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;
#
#         &lt;/body&gt;
#         &lt;/html&gt;
#         "
#                 width="800px" height="500px"
#                 frameborder="0" scrolling="no" sandbox="allow-scripts allow-same-origin allow-downloads">
#         </iframe>

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c =(
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add("",[list(z) for z in zip(wd, num)],radius=["20%", "55%"],center=[240,220],rosetype='radius')
    .add("",[list(z) for z in zip(wd, num)],radius=["20%", "55%"],center=[620,220],rosetype='area')
    .set_global_opts(title_opts=opts.TitleOpts(title="玫瑰图"))
)
display_chart(c)
# Out:
#         <iframe srcdoc="
#         &lt;!DOCTYPE html&gt;
#         &lt;html&gt;
#         &lt;head&gt;
#             &lt;meta charset=&quot;UTF-8&quot;&gt;
#             &lt;script src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#         &lt;/head&gt;
#         &lt;body style=&quot;margin:0; padding:0;&quot;&gt;
#             &lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://assets.pyecharts.org/assets/v6/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;dd37963289f5453d8c5d28fb9b107ad5&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_dd37963289f5453d8c5d28fb9b107ad5 = echarts.init(
#             document.getElementById(&#x27;dd37963289f5453d8c5d28fb9b107ad5&#x27;), &#x27;white&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_dd37963289f5453d8c5d28fb9b107ad5 = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
#     &quot;animationEasing&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelay&quot;: 0,
#     &quot;animationDurationUpdate&quot;: 300,
#     &quot;animationEasingUpdate&quot;: &quot;cubicOut&quot;,
#     &quot;animationDelayUpdate&quot;: 0,
#     &quot;aria&quot;: {
#         &quot;enabled&quot;: false
#     },
#     &quot;series&quot;: [
#         {
#             &quot;type&quot;: &quot;pie&quot;,
#             &quot;colorBy&quot;: &quot;data&quot;,
#             &quot;legendHoverLink&quot;: true,
#             &quot;selectedMode&quot;: false,
#             &quot;selectedOffset&quot;: 10,
#             &quot;clockwise&quot;: true,
#             &quot;startAngle&quot;: 90,
#             &quot;minAngle&quot;: 0,
#             &quot;minShowLabelAngle&quot;: 0,
#             &quot;avoidLabelOverlap&quot;: true,
#             &quot;stillShowZeroSum&quot;: true,
#             &quot;percentPrecision&quot;: 2,
#             &quot;showEmptyCircle&quot;: true,
#             &quot;emptyCircleStyle&quot;: {
#                 &quot;color&quot;: &quot;lightgray&quot;,
#                 &quot;borderColor&quot;: &quot;#000&quot;,
#                 &quot;borderWidth&quot;: 0,
#                 &quot;borderType&quot;: &quot;solid&quot;,
#                 &quot;borderDashOffset&quot;: 0,
#                 &quot;borderCap&quot;: &quot;butt&quot;,
#                 &quot;borderJoin&quot;: &quot;bevel&quot;,
#                 &quot;borderMiterLimit&quot;: 10,
#                 &quot;opacity&quot;: 1
#             },
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6559\u6388&quot;,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u526f\u6559\u6388&quot;,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u8bb2\u5e08&quot;,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u52a9\u6559&quot;,
#                     &quot;value&quot;: 12
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5176\u4ed6&quot;,
#                     &quot;value&quot;: 8
#                 }
#             ],
#             &quot;radius&quot;: [
#                 &quot;20%&quot;,
#                 &quot;55%&quot;
#             ],
#             &quot;center&quot;: [
#                 240,
#                 220
#             ],
#             &quot;roseType&quot;: &quot;radius&quot;,
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;labelLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;showAbove&quot;: false,
#                 &quot;length&quot;: 15,
#                 &quot;length2&quot;: 15,
#                 &quot;smooth&quot;: false,
#                 &quot;minTurnAngle&quot;: 90,
#                 &quot;maxSurfaceAngle&quot;: 90
#             }
#         },
#         {
#             &quot;type&quot;: &quot;pie&quot;,
#             &quot;colorBy&quot;: &quot;data&quot;,
#             &quot;legendHoverLink&quot;: true,
#             &quot;selectedMode&quot;: false,
#             &quot;selectedOffset&quot;: 10,
#             &quot;clockwise&quot;: true,
#             &quot;startAngle&quot;: 90,
#             &quot;minAngle&quot;: 0,
#             &quot;minShowLabelAngle&quot;: 0,
#             &quot;avoidLabelOverlap&quot;: true,
#             &quot;stillShowZeroSum&quot;: true,
#             &quot;percentPrecision&quot;: 2,
#             &quot;showEmptyCircle&quot;: true,
#             &quot;emptyCircleStyle&quot;: {
#                 &quot;color&quot;: &quot;lightgray&quot;,
#                 &quot;borderColor&quot;: &quot;#000&quot;,
#                 &quot;borderWidth&quot;: 0,
#                 &quot;borderType&quot;: &quot;solid&quot;,
#                 &quot;borderDashOffset&quot;: 0,
#                 &quot;borderCap&quot;: &quot;butt&quot;,
#                 &quot;borderJoin&quot;: &quot;bevel&quot;,
#                 &quot;borderMiterLimit&quot;: 10,
#                 &quot;opacity&quot;: 1
#             },
#             &quot;data&quot;: [
#                 {
#                     &quot;name&quot;: &quot;\u6559\u6388&quot;,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u526f\u6559\u6388&quot;,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u8bb2\u5e08&quot;,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u52a9\u6559&quot;,
#                     &quot;value&quot;: 12
#                 },
#                 {
#                     &quot;name&quot;: &quot;\u5176\u4ed6&quot;,
#                     &quot;value&quot;: 8
#                 }
#             ],
#             &quot;radius&quot;: [
#                 &quot;20%&quot;,
#                 &quot;55%&quot;
#             ],
#             &quot;center&quot;: [
#                 620,
#                 220
#             ],
#             &quot;roseType&quot;: &quot;area&quot;,
#             &quot;label&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;margin&quot;: 8,
#                 &quot;richInheritPlainLabel&quot;: true,
#                 &quot;valueAnimation&quot;: false
#             },
#             &quot;labelLine&quot;: {
#                 &quot;show&quot;: true,
#                 &quot;showAbove&quot;: false,
#                 &quot;length&quot;: 15,
#                 &quot;length2&quot;: 15,
#                 &quot;smooth&quot;: false,
#                 &quot;minTurnAngle&quot;: 90,
#                 &quot;maxSurfaceAngle&quot;: 90
#             }
#         }
#     ],
#     &quot;legend&quot;: [
#         {
#             &quot;data&quot;: [
#                 &quot;\u6559\u6388&quot;,
#                 &quot;\u526f\u6559\u6388&quot;,
#                 &quot;\u8bb2\u5e08&quot;,
#                 &quot;\u52a9\u6559&quot;,
#                 &quot;\u5176\u4ed6&quot;
#             ],
#             &quot;selected&quot;: {},
#             &quot;show&quot;: true,
#             &quot;padding&quot;: 5,
#             &quot;itemGap&quot;: 10,
#             &quot;itemWidth&quot;: 25,
#             &quot;itemHeight&quot;: 14,
#             &quot;backgroundColor&quot;: &quot;transparent&quot;,
#             &quot;borderColor&quot;: &quot;#ccc&quot;,
#             &quot;borderRadius&quot;: 0,
#             &quot;pageButtonItemGap&quot;: 5,
#             &quot;pageButtonPosition&quot;: &quot;end&quot;,
#             &quot;pageFormatter&quot;: &quot;{current}/{total}&quot;,
#             &quot;pageIconColor&quot;: &quot
