# %%
from pyecharts_jupyter_exporter import display_chart, get_chart_urls, render_chart

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts import options as opts    
from pyecharts.charts import Page, Pie
L1=['教授','副教授','讲师','助教','其他']
num  = [20,30,10,12,8]
#绘制饼图
c = (
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add(series_name="",data_pair=[list(z) for z in zip(L1,num)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类别比例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

#c.load_javascript()
#c.render_notebook()
render_chart(c)
# Out:
# <script>
#         (function() {
#             var urls = ["https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js"];
#
#             function loadScript(url) {
#                 return new Promise(function(resolve, reject) {
#                     if (window.__loaded_scripts && window.__loaded_scripts[url]) {
#                         resolve();
#                         return;
#                     }
#                     var script = document.createElement('script');
#                     script.src = url;
#                     script.onload = function() {
#                         if (!window.__loaded_scripts) window.__loaded_scripts = {};
#                         window.__loaded_scripts[url] = true;
#                         resolve();
#                     };
#                     script.onerror = reject;
#                     document.head.appendChild(script);
#                 });
#             }
#
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = (
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add("",[list(z) for z in zip(wd, num)],radius = ["40%", "75%"]) # 圆环的粗细和大小  
    .set_global_opts( 
        title_opts=opts.TitleOpts(title="Pie-Radius"),
        legend_opts=opts.LegendOpts( orient="vertical", pos_top="5%", pos_left="2%" )
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
render_chart(c)
# Out:
#         <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;3eb22e084adb48ec844283293f31060f&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_3eb22e084adb48ec844283293f31060f = echarts.init(
#             document.getElementById(&#x27;3eb22e084adb48ec844283293f31060f&#x27;), &#x27;white&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_3eb22e084adb48ec844283293f31060f = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c =(
    Pie(init_opts=opts.InitOpts(width="800px"))
    .add("",[list(z) for z in zip(wd, num)],radius=["20%", "55%"],center=[240,220],rosetype='radius')
    .add("",[list(z) for z in zip(wd, num)],radius=["20%", "55%"],center=[620,220],rosetype='area')
    .set_global_opts(title_opts=opts.TitleOpts(title="玫瑰图"))
)
render_chart(c)
# Out:
#         <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;title&gt;Awesome-pyecharts&lt;/title&gt;
#                 &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/gh/pyecharts/pyecharts-assets@master/assets/echarts.min.js&quot;&gt;&lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body &gt;
#     &lt;div id=&quot;1f335d4fe7a342b88007d966bf64373b&quot; class=&quot;chart-container&quot; style=&quot;width:800px; height:500px; &quot;&gt;&lt;/div&gt;
#     &lt;script&gt;
#         var chart_1f335d4fe7a342b88007d966bf64373b = echarts.init(
#             document.getElementById(&#x27;1f335d4fe7a342b88007d966bf64373b&#x27;), &#x27;white&#x27;, {renderer: &#x27;canvas&#x27;, locale: &#x27;ZH&#x27;});
#         var option_1f335d4fe7a342b88007d966bf64373b = {
#     &quot;animation&quot;: true,
#     &quot;animationThreshold&quot;: 2000,
#     &quot;animationDuration&quot;: 1000,
# ...
